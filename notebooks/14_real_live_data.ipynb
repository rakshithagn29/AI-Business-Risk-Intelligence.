# %%
import pandas as pd
import os, sys
import warnings
warnings.filterwarnings('ignore')

BASE = r"C:\Users\Admin\OneDrive\Desktop\AI-Business-Risk-Intelligence"
sys.path.append(BASE)

from src.real_sentiment_collector import collect_and_save

df_live, summary = collect_and_save()

if df_live is not None:
    print("\n📊 SUMMARY:")
    for k, v in summary.items():
        print(f"  {k}: {v}")
    print("\n📰 Sample headlines:")
    for title in df_live['title'].head(5):
        print(f"  - {title}")
